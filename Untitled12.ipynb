# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanashreeyadav/Spoon-Knife/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
path=input("Enter the file path:")
file=pd.read_csv(path)
print(file)
# Out:
# Enter the file path:/content/tested.csv
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
file.head()#printing first five rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
file.isnull().head()#checking for null values in first five rows
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False   True     False
# 2  False   True     False
# 3  False   True     False
# 4  False   True     False

# %%
file.isnull().sum()#checking overall null values in the attributes
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
file[file["Fare"].isnull()]#one fare value that was null
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
file.shape#it gives the no. of observations and attributes
# Out:
# (418, 12)

# %%
file.dropna(how ="any").shape #it drops or deletes the the row which as any attribute null
# Out:
# (87, 12)

# %%
file[file.Fare.isnull()]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
file.dropna().shape
# Out:
# (87, 12)

# %%
file.shape
# Out:
# (418, 12)

# %%
file['Fare'].fillna(file.Fare.median(),inplace=True)#here we handled the missing value of fare with media and now showing 0 
file.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
file['Sex'].replace(['male','female'],[0,1],inplace=True)
print(file)
#file.head()
#replacing categorical data with numbers here categrical data gender 
#inplace=True is used to make change in file
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    0  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                                Wirz, Mr. Albert    0  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
plt.figure(figsize=(15,15))
file.boxplot()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
file['Sex'].replace(['male','female'],[0,1],inplace=True)
file.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                              Wirz, Mr. Albert    0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
file[file.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    0  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                                Wirz, Mr. Albert    0  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
#normalized data
y_array=np.array([34.5	,47.0	,62.0	,27.0	,22.0	])
normalized =preprocessing.normalize([y_array])
print("Normalized age=",normalized)
# Out:
# Normalized age= [[0.3751718  0.51110361 0.67422179 0.29361271 0.23923999]]

# %%
z_array=np.array([7.8292	,7.0000,	9.6875	,8.6625	,12.2875])
normalize =preprocessing.normalize([z_array])
print("Normalized Fare=",normalize)
# Out:
# Normalized Fare= [[0.37748487 0.337505   0.46708281 0.41766243 0.59244181]]

# %%
z_array=np.array([330911	,363272,	240276	,315154	,3101298])
normalize =preprocessing.normalize([z_array])
print("Normalized Ticket=",normalize)
# Out:
# Normalized Ticket= [[0.10455664 0.11478162 0.07591906 0.09957797 0.9799049 ]]
